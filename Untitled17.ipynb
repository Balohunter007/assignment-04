# %% [markdown]
# <a href="https://colab.research.google.com/github/Balohunter007/assignment-04/blob/main/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Enter the price of the House you wish to buy
print("Enter the house price")
price =input("650000")

#Enter your Credit Score
print("Enter your Credit Score")
CreditScore =input("580")

# Enter the first name
print("Enter the first name")
first_name = input("Dolapo")

# Enter the last_name
print("Enter the last name")
last_name = input("Odebiyi")

fullnames = first_name + "" + last_name

# Enter the email
print("Enter the email address")
email = input("itzdolarp406@gmail.com")

# Enter the phone number
print("Enter the phone number")
phone = input("7133075420")

# Enter the mailing address
print("Enter the mailing address")
mailing = input("9401 Beechnut Str")

# Enter the City
print("Enter the City")
City = input("Houston")

# Enter the State
print("Enter the State")
State = input("TX")

# Enter the Zipcode
print("Enter the zipcode")
zipcode = input("77036")


#Qualify for loans with the best interest rates
Credit_Score=input("Enter Credit Score")
print("Credit Score: "+ "580")
down_Payment =input("0.0 * 600000")
print("Excellent Credit")
print("Zero Down Payment: ")

#Usually qualify for loans with the best interest rates
CreditScore >= ("740 and 779:")
print("Very Good")
downPayment = float(0.1 * 600000)
print("Downpayment: " + str(60000))

#May face slightly higher loan Interest rates
CreditScore >= "720 and 739:"
print ("Above Average")
downPayment = float(0.3 * 600000)
print("Downpayment: " + str(downPayment))

#May qualify for most loans of higher Interest rates
CreditScore >= "680 and 719:"
print ("Average")
downPayment = float(0.6 * 600000)
print("Downpayment: " + str(downPayment))

#May qualify for most loans at significantly higher Interest rates
CreditScore >= "620 and 679:"
print ("Below Average")
downPayment = float(0.18 * 600000)
print("Downpayment: " + str(downPayment))

#Usually has some credit issues; will probably
CreditScore >= "580 and 619:"
print("Below Average")
downPayment = float(0.18 * 600000)
print("Downpayment: " + str(downPayment))

# Usually has some credit issues; will probably not 
CreditScore >= "580 and 619:"
print ("Poor Credit Score")
downPayment = float(0.2 * 600000)
print("Downpayment: " + str(downPayment))

#Facing extreme credit issue
CreditScore < "520:"
print ("Poor Credit Score")
downPayment = float(0.25 * 600000)
print("Downpayment: " + str(downPayment))
"else:"
print("invalid output")

print("First name : " + "Dolapo Odebiyi")
print("Physical address: " + "9401 Beechnut Str")
print("City : " + "Houston")
print("State : " + "TX")
print("Zipcode : " + "77036")
# Out:
# Enter the house price
# 650000
# Enter your Credit Score
# 580
# Enter the first name
# Dolapo
# Enter the last name
# Odebiyi
# Enter the email address
# itzdolarp406@gmail.com
# Enter the phone number
# 7133075420
# Enter the mailing address
# 9401 Beechnut Str
# Enter the City
# Houston
# Enter the State
# TX
# Enter the zipcode
# 77036
# Enter Credit Score
# Credit Score: 580
# 0.0 * 600000
# Excellent Credit
# Zero Down Payment:
# Very Good
# Downpayment: 60000
# Above Average
# Downpayment: 180000.0
# Average
# Downpayment: 360000.0
# Below Average
# Downpayment: 108000.0
# Below Average
# Downpayment: 108000.0
# Poor Credit Score
# Downpayment: 120000.0
# Poor Credit Score
# Downpayment: 150000.0
# invalid output
# First name : Dolapo Odebiyi
# Physical address: 9401 Beechnut Str
# City : Houston
# State : TX
# Zipcode : 77036
